# %%
from openpyxl import Workbook
from openpyxl import load_workbook
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import string

# %%
directory_in_str = "\\\\?\\C:\\Users\\Edward\\OneDrive\\Documents\\University\\Fourth Year\\Thesis\\HemicelluloseThesis\\ExcelDataCollection\\Complete\\"
directory_in_str2 = "\\\\?\\C:\\Users\\Edward\\OneDrive\\Documents\\University\\Fourth Year\\Thesis\\HemicelluloseThesis\\ExcelDataCollection\\Complete\\ThesisOnlyDataSet\\"

#print(directory_in_str)
directory = os.fsencode(directory_in_str)
directory2 = os.fsencode(directory_in_str2)

COLUMN_NAMES=['TotalT','Temp','LSR','CA','Size','Mass','Moisture', 'IsoT', 'HeatT', 'Ramp', 'F_A', 'F_Gal', 'F_Glu',
            'F_X', 'F_M', 'F_R', 'A', 'Gal', 'Glu','X', 'M', 'R', 'Furf', 'HMF', 'Source']

masterDF = pd.DataFrame(columns=COLUMN_NAMES)
#print(len(masterDF.columns))
#print(masterDF.columns)

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    absPath = directory_in_str + filename
    if filename.endswith(".xlsx"): 
        wb = load_workbook(filename = absPath, data_only = True) 
        ws = wb["Data"]
        ws.delete_rows(1,2)
        df = pd.DataFrame(ws.values, columns=COLUMN_NAMES[:-1])
        df['Source'] = filename
        #print("1", df.at[1, 'Temp'])
        masterDF = pd.concat([masterDF, df], ignore_index=True)
        #masterDF = masterDF.append(df)
        #print("2",masterDF.at[1, 'Temp'])
        continue
    else:
        continue
        

for file in os.listdir(directory2):
    filename = os.fsdecode(file)
    print(filename)
    absPath = directory_in_str2 + filename
    if filename.endswith(".xlsx"): 
        wb = load_workbook(filename = absPath, data_only = True) 
        ws = wb["Data"]
        ws.delete_rows(1,2)
        df = pd.DataFrame(ws.values, columns=COLUMN_NAMES[:-1])
        df['Source'] = filename
        #print("1", df.at[1, 'Temp'])
        masterDF = pd.concat([masterDF, df], ignore_index=True)
        #masterDF = masterDF.append(df)
        #print("2",masterDF.at[1, 'Temp'])
        continue
    else:
        continue

        
#masterDF = masterDF.astype(float)
masterDF.reset_index()

#Deleting empty rows
rowsToDelete = []
for i in masterDF.index:
    if masterDF.at[i, 'X'] is None or pd.isnull(masterDF.at[i, 'X']) or masterDF.at[i, 'F_X'] is None or pd.isnull(masterDF.at[i, 'F_X']):
        rowsToDelete.append(i)

masterDF = masterDF.drop(rowsToDelete, axis=0)
masterDF.reset_index()

masterDF.to_csv("data.csv", index=False)

for i in masterDF.index:
    if masterDF.at[i, 'Ramp'] is None or pd.isnull(masterDF.at[i, 'Ramp']):
        masterDF.at[i, 'Ramp'] = (masterDF.at[i, 'Temp'] - 25) / masterDF.at[i, 'HeatT']
    if masterDF.at[i, 'HeatT'] is None or pd.isnull(masterDF.at[i, 'HeatT']):
        masterDF.at[i, 'HeatT'] = (masterDF.at[i, 'Temp'] - 25) / masterDF.at[i, 'Ramp']
    #print(type(masterDF.at[i, 'TotalT']))
    #print((masterDF.at[i, 'Temp']))
    if masterDF.at[i, 'TotalT'] is None or pd.isnull(masterDF.at[i, 'TotalT']):
        masterDF.at[i, 'TotalT'] =  masterDF.at[i, 'HeatT'] +  masterDF.at[i, 'IsoT']
    if masterDF.at[i, 'IsoT'] is None or pd.isnull(masterDF.at[i, 'IsoT']):
        masterDF.at[i, 'IsoT'] =  masterDF.at[i, 'TotalT'] -  masterDF.at[i, 'HeatT']
    if masterDF.at[i, 'TotalT'] == 0:
        masterDF.at[i, 'IsoT'] =  0
        masterDF.at[i, 'HeatT'] =  0
        
masterDF['TotalT'].fillna(masterDF.at[i, 'HeatT'] +  masterDF.at[i, 'IsoT'])


        
masterDF['X'].fillna(0, inplace=True)

#Converting Celsius to Kelvin
masterDF['Temp'] = masterDF['Temp'] + 273.15

#Making An Identifier Column to use instead of paper names
unique_papers = masterDF['Source'].unique()
paper_dict = dict(enumerate(unique_papers))
#swapping key and values
paper_dict = dict((v,k) for k,v in paper_dict.items())
alphabet = string.ascii_uppercase

masterDF['ID'] = masterDF['Source']
for i in masterDF.index:
    masterDF.at[i, 'ID'] = alphabet[paper_dict[masterDF.at[i, 'Source']]]

#This makes everything numeric
masterDF.to_csv("data.csv", index=False)
masterDF = pd.read_csv("data.csv")


#Creating Yield, Ro and P Factor
masterDF['Yield'] = 100 * masterDF['X'] * masterDF['LSR'] / (1000 * (masterDF['F_X']/100)) #1000 is density of water in g/L, X is in g/L

#P = exp(40.48 - 15106/T) * t, with T in Kelvin, t in hours
masterDF['P'] = np.exp(40.48 - 15106/masterDF['Temp']) * masterDF['IsoT']/60
masterDF['logP'] = masterDF['P']

#Ro = t * exp((T - 100)/14.75), t in minutes, T in Celsius
masterDF['Ro'] = masterDF['IsoT'] * np.exp(((masterDF['Temp'] -273.15) - 100)/14.75)
masterDF['logRo'] = masterDF['Ro']

for i in masterDF.index:
    if masterDF.at[i, 'logRo'] != 0:
        masterDF.at[i, 'logRo'] = np.log( masterDF.at[i, 'logRo'])
    if masterDF.at[i, 'logP'] != 0:
        masterDF.at[i, 'logP'] = np.log( masterDF.at[i, 'logP'])
# Out:
# Autohydrolysis Pretreatment of Mixed Hardwoods to Extract Value Prior to Combustion.xlsx
# Bioethanol production from hydrothermally pretreated Eucalyptus globulus wood.xlsx
# Combined autohydrolysis and alkali pretreatments for cellulose enzymatic hydrolysis of Eucalyptus grandis wood.xlsx
# Comparative evaluation of autohydrolysis and acid-catalyzed hydrolysis of Eucalyptus globulus wood.xlsx
# Comparative study on the yield and characterization of hemicelluloses isolated with hydrothermal.xlsx
# Effect of Liquid to Solid Ratio on Autohydrolysis of Eucalyptus globulus Wood Meal.xlsx
# Ethanol Production from Residual Wood Chips of Cellulose Industry- Acid Pretreatment Investigation.xlsx
# Evaluation of the effect of the dilute acid hydrolysis on sugars release from olive prunings.xlsx
# Evaluation of the Kinetics .xlsx
# HemicellulosesFromStonePineHolmOakAndNorway SpruceWithSubcriticalWaterExtraction.xlsx
# Hydrothermal Pretreatment Conditions to Enhance Ethanol Production from Poplar Biomass.xlsx
# HydrothermalTreatmentOfEucalyptusWoodEffectsOnIonPermeabilityAndMaterialRemoving.xlsx
# Investigation of conditions for dilute acid pretreatment for improving xylose solubilization and glucose production by supercritical water hydrolysis from Quercus mongolica.xlsx
# Kinetic Characterization of Biomass Dilute Sulfuric Acid Hydrolysis- Mixtures of Hardwoods, Softwood, and Switchgrass.xlsx
# Kinetic Characterization of Xylose Monomer and Oligomer Concentrations during Dilute Acid Pretreatment of Lignocellulosic Biomass from Forests and Switchgrass.xlsx
# Liquid Hot Water Pretreatment of Olive Tree Pruning Residues.xlsx
# Optimization of furfural production by acid hydrolysis of Eucalyptus globulus in two stages.xlsx
# Optimization of the Pretreatment of Prosopis Nigra Sawdust for the Production of Fermentable Sugars.xlsx
# Prehydrolysis of Hardwoods with Dilute Sulfuric Acid (1).xlsx
# Prehydrolysis of Hardwoods with Dilute Sulfuric Acid.xlsx
# Pretreatment of hardwood chips via autohydrolysis supported by acetic and formic acid.xlsx
# Production of xylooligosaccharides and monosaccharides from poplar by a two step acetic acid and peroxide acetic acid pretreatment.xlsx
# Response surface optimization of oxalic acid pretreatment of yellow poplar (Liriodendron tulipifera) for production of glucose and xylose monosaccarides.xlsx
# Subcritical water and dilute acid pretreatments for bioethanol production from Melaleuca leucadendron shedding bark.xlsx
# Sugar yields from dilute oxalic acid pretreatment of maple wood compared to those with other dilute acids and hot water.xlsx
# ThesisOnlyDataSet
# DesignOfProcessParametersForProudctionOfXylose.xlsx
# EffectofEucalytpusGlobulusWoodAutohydrolysis.xlsx
# ExtractionOfXylansFromHardwoodChips.xlsx
# EXTRACTION_OF_HEMICELLULOSES_ BY_ ACID.xlsx
# Generation of xylose solutions from Eucalyptus globulus wood.xlsx
# HemicelluloseExtractionOfMixedSouthernHardwood.xlsx
# HemicelluloseRemovalFromHardwood.xlsx
# HotWaterPretreatment.xlsx
# KineticStuidesOfAcidHyrolysisOfMerantiWood.xlsx
# MildAutohydrolysisAnEnvironmentallyFriendlyTechnologXyl.xlsx
# OptimizationofHydrothermalACS.xlsx
# OptimizationOfHydrothermalCHEMPUP.xlsx
# PrehydrolysisOfEucalyptusWoodWithDiluteSulphuricAcidAtmostpheric.xlsx
# PrehydrolysisOfEucalyptusWoodWithDiluteSulphuricAcidAutoclave.xlsx
# ProductionOfXyloseFromMerantiWood.xlsx
# QuantitativeAnalysisofSugarsInWoodHydrolyzates.xlsx
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2048ff417729> in <module>()
#      67 for i in masterDF.index:
#      68     if masterDF.at[i, 'Ramp'] is None or pd.isnull(masterDF.at[i, 'Ramp']):
# ---> 69         masterDF.at[i, 'Ramp'] = (masterDF.at[i, 'Temp'] - 25) / masterDF.at[i, 'HeatT']
#      70     if masterDF.at[i, 'HeatT'] is None or pd.isnull(masterDF.at[i, 'HeatT']):
#      71         masterDF.at[i, 'HeatT'] = (masterDF.at[i, 'Temp'] - 25) / masterDF.at[i, 'Ramp']
#
# TypeError: unsupported operand type(s) for /: 'float' and 'NoneType'
